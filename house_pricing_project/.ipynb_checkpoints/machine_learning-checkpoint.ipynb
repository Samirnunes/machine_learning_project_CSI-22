# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ---

# %% [markdown]
# ## Importing data

# %%
y_train_path = os.path.join('data', 'preprocessed_y_train.csv')
X_train_path = os.path.join('data', 'preprocessed_X_train.csv')
X_test_path = os.path.join('data', 'preprocessed_X_test.csv')

y_train = pd.read_csv(y_train_path, index_col = 'Id')
X_train = pd.read_csv(X_train_path, index_col = 'Id')
X_test = pd.read_csv(X_test_path, index_col = 'Id')

# %%
y_train.head()
# Out:
#     SalePrice
# Id
# 1      208500
# 2      181500
# 3      223500
# 4      140000
# 5      250000

# %%
X_train.head()
# Out:
#     LotFrontage   LotArea  Alley  LotShape  LandSlope  OverallQual  \
# Id
# 1     -0.208034 -0.207142    0.5  0.000000        0.0     0.651479
# 2      0.409895 -0.091886    0.5  0.000000        0.0    -0.071836
# 3     -0.084449  0.073480    0.5  0.333333        0.0     0.651479
# 4     -0.414011 -0.096897    0.5  0.333333        0.0     0.651479
# 5      0.574676  0.375148    0.5  0.333333        0.0     1.374795
#
#     OverallCond  YearBuilt  YearRemodAdd  MasVnrArea  ...  Exterior1st_Stucco  \
# Id                                                    ...
# 1     -0.517200   1.050994      0.878668    0.510015  ...                 0.0
# 2      2.179628   0.156734     -0.429577   -0.572835  ...                 0.0
# 3     -0.517200   0.984752      0.830215    0.322174  ...                 0.0
# 4     -0.517200  -1.863632     -0.720298   -0.572835  ...                 0.0
# 5     -0.517200   0.951632      0.733308    1.360826  ...                 0.0
#
#     Exterior1st_VinylSd  Exterior1st_Wd Sdng  Exterior1st_WdShing  \
# Id
# 1                   1.0                  0.0                  0.0
# 2                   0.0                  0.0                  0.0
# 3                   1.0                  0.0                  0.0
# 4                   0.0                  1.0                  0.0
# 5                   1.0                  0.0                  0.0
#
#     Exterior1st_infrequent_sklearn  Foundation_BrkTil  Foundation_CBlock  \
# Id
# 1                              0.0                0.0                0.0
# 2                              0.0                0.0                1.0
# 3                              0.0                0.0                0.0
# 4                              0.0                1.0                0.0
# 5                              0.0                0.0                0.0
#
#     Foundation_PConc  Foundation_Slab  Foundation_infrequent_sklearn
# Id
# 1                1.0              0.0                            0.0
# 2                0.0              0.0                            0.0
# 3                1.0              0.0                            0.0
# 4                0.0              0.0                            0.0
# 5                1.0              0.0                            0.0
#
# [5 rows x 197 columns]

# %%
X_test.head()
# Out:
#       LotFrontage   LotArea  Alley  LotShape  LandSlope  OverallQual  \
# Id
# 1461     0.409895  0.110763    0.5  0.000000        0.0    -0.795151
# 1462     0.451090  0.375850    0.5  0.333333        0.0    -0.071836
# 1463     0.162723  0.332053    0.5  0.333333        0.0    -0.795151
# 1464     0.327504 -0.054002    0.5  0.333333        0.0    -0.071836
# 1465    -1.114330 -0.552407    0.5  0.333333        0.0     1.374795
#
#       OverallCond  YearBuilt  YearRemodAdd  MasVnrArea  ...  \
# Id                                                      ...
# 1461     0.381743  -0.340077     -1.156380   -0.572835  ...
# 1462     0.381743  -0.439440     -1.301740    0.023838  ...
# 1463    -0.517200   0.852269      0.636400   -0.572835  ...
# 1464     0.381743   0.885390      0.636400   -0.462340  ...
# 1465    -0.517200   0.686666      0.345679   -0.572835  ...
#
#       Exterior1st_Stucco  Exterior1st_VinylSd  Exterior1st_Wd Sdng  \
# Id
# 1461                 0.0                  1.0                  0.0
# 1462                 0.0                  0.0                  1.0
# 1463                 0.0                  1.0                  0.0
# 1464                 0.0                  1.0                  0.0
# 1465                 0.0                  0.0                  0.0
#
#       Exterior1st_WdShing  Exterior1st_infrequent_sklearn  Foundation_BrkTil  \
# Id
# 1461                  0.0                             0.0                0.0
# 1462                  0.0                             0.0                0.0
# 1463                  0.0                             0.0                0.0
# 1464                  0.0                             0.0                0.0
# 1465                  0.0                             0.0                0.0
#
#       Foundation_CBlock  Foundation_PConc  Foundation_Slab  \
# Id
# 1461                1.0               0.0              0.0
# 1462                1.0               0.0              0.0
# 1463                0.0               1.0              0.0
# 1464                0.0               1.0              0.0
# 1465                0.0               1.0              0.0
#
#       Foundation_infrequent_sklearn
# Id
# 1461                            0.0
# 1462                            0.0
# 1463                            0.0
# 1464                            0.0
# 1465                            0.0
#
# [5 rows x 197 columns]

# %% [markdown]
# ---

# %% [markdown]
# ## Importing models

# %%
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_regression

# %% [markdown]
# ## 1) XGBoost

# %% [markdown]
# ### Standard parameters

# %%
std_params = {'random_state': 0,
              'n_estimators': 10000,
               'max_depth': 6,
               'early_stopping_rounds': 10,
               'learning_rate': 0.05,
               'reg_lambda': 1,
               'reg_alpha': 1,
               'predictor': 'gpu_predictor'}

# %% [markdown]
# ### Creating and fitting model

# %%
params = {'random_state': 0,
          'n_estimators': 10000,
          'max_depth': 6,
          'early_stopping_rounds': 10,
          'learning_rate': 0.05,
          'reg_lambda': 1,
          'reg_alpha': 1,
          'predictor': 'gpu_predictor'}

def create_xgb_model(params):
    xgb_model = XGBRegressor(random_state = params['random_state'],
                       n_estimators = params['n_estimators'], 
                       max_depth = params['max_depth'], 
                       learning_rate = params['learning_rate'],
                       early_stopping_rounds = params['early_stopping_rounds'],
                       reg_lambda = params['reg_lambda'], 
                       reg_alpha = params['reg_alpha'],
                       predictor = params['predictor'])
    return xgb_model

# %% [markdown]
# ### Feature Selection

# %%
select_k_best = SelectKBest(mutual_info_regression, k=150)
X_train = pd.DataFrame(select_k_best.fit_transform(X_train, y_train), index=X_train.index, columns=select_k_best.get_feature_names_out())
X_test = pd.DataFrame(select_k_best.transform(X_test), index=X_test.index, columns=select_k_best.get_feature_names_out())
# Out:
# C:\Users\samir\anaconda3\envs\csi22\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# ### Using KFold cross-validation method to analyze generatization capability

# %%
import warnings
warnings.filterwarnings('ignore')

eval_set = [(X_train, y_train)]

indexes = np.array(X_train.index)
rand = np.random.RandomState(params['random_state'])
rand.shuffle(indexes)
X_shuffled = X_train.loc[indexes]
y_shuffled = y_train.loc[indexes]

folds = 5
kf = KFold(n_splits = folds)
kfold_scores = []

for (train_indexes, val_indexes) in kf.split(X_train):
    X_train_kfold = X_shuffled.iloc[train_indexes].copy()
    y_train_kfold = y_shuffled.iloc[train_indexes].copy()
    X_val_kfold = X_shuffled.iloc[val_indexes].copy()
    y_val_kfold = y_shuffled.iloc[val_indexes].copy()
    
    model = create_xgb_model(params)
    model.fit(X_train_kfold, y_train_kfold, eval_metric = 'rmse', eval_set = eval_set, verbose = 0)
    y_pred = model.predict(X_val_kfold)
    kfold_scores.append(np.sqrt(mean_squared_error(np.log(y_val_kfold), np.log(y_pred))))
    
print(f'KFold final score: {sum(kfold_scores)/len(kfold_scores)}')
# Out:
# KFold final score: 0.1277138416732383

# %% [markdown]
# Important:
# **Kfold final score is an estimate of the competition score.** However, it's certainly overestimated or underestimated.

# %% [markdown]
# ---

# %% [markdown]
# ## Exporting result to submission

# %%
xgb_model = create_xgb_model(params)
xgb_model.fit(X_train, y_train, eval_metric = 'rmse', eval_set = eval_set)
y_pred = xgb_model.predict(X_test)
y_pred = pd.DataFrame(y_pred, index = X_test.index, columns = ['SalePrice'])
# Out:
# [0]	validation_0-rmse:188156.83313
# [1]	validation_0-rmse:179210.07283
# [2]	validation_0-rmse:170710.72811
# [3]	validation_0-rmse:162634.24016
# [4]	validation_0-rmse:154969.42321
# [5]	validation_0-rmse:147655.27749
# [6]	validation_0-rmse:140709.68990
# [7]	validation_0-rmse:134107.55472
# [8]	validation_0-rmse:127839.21191
# [9]	validation_0-rmse:121895.94087
# [10]	validation_0-rmse:116219.55146
# [11]	validation_0-rmse:110828.95375
# [12]	validation_0-rmse:105722.53959
# [13]	validation_0-rmse:100857.30985
# [14]	validation_0-rmse:96223.08851
# [15]	validation_0-rmse:91819.72198
# [16]	validation_0-rmse:87637.38988
# [17]	validation_0-rmse:83678.92103
# [18]	validation_0-rmse:79888.96041
# [19]	validation_0-rmse:76284.80777
# [20]	validation_0-rmse:72861.01324
# [21]	validation_0-rmse:69618.96302
# [22]	validation_0-rmse:66533.61794
# [23]	validation_0-rmse:63600.94080
# [24]	validation_0-rmse:60815.52908
# [25]	validation_0-rmse:58150.38045
# [26]	validation_0-rmse:55630.24345
# [27]	validation_0-rmse:53217.65435
# [28]	validation_0-rmse:50934.58868
# [29]	validation_0-rmse:48765.83371
# [30]	validation_0-rmse:46695.00335
# [31]	validation_0-rmse:44745.64328
# [32]	validation_0-rmse:42880.53028
# [33]	validation_0-rmse:41116.02965
# [34]	validation_0-rmse:39445.86658
# [35]	validation_0-rmse:37837.60227
# [36]	validation_0-rmse:36312.24964
# [37]	validation_0-rmse:34871.93566
# [38]	validation_0-rmse:33501.43657
# [39]	validation_0-rmse:32195.42621
# [40]	validation_0-rmse:30959.67194
# [41]	validation_0-rmse:29796.22942
# [42]	validation_0-rmse:28692.18729
# [43]	validation_0-rmse:27646.37555
# [44]	validation_0-rmse:26639.99061
# [45]	validation_0-rmse:25688.02539
# [46]	validation_0-rmse:24795.84893
# [47]	validation_0-rmse:23932.60953
# [48]	validation_0-rmse:23115.02395
# [49]	validation_0-rmse:22355.81818
# [50]	validation_0-rmse:21622.60790
# [51]	validation_0-rmse:20940.42598
# [52]	validation_0-rmse:20289.88922
# [53]	validation_0-rmse:19668.45807
# [54]	validation_0-rmse:19085.71133
# [55]	validation_0-rmse:18523.16967
# [56]	validation_0-rmse:17982.43030
# [57]	validation_0-rmse:17484.38513
# [58]	validation_0-rmse:17002.28797
# [59]	validation_0-rmse:16532.58099
# [60]	validation_0-rmse:16093.71011
# [61]	validation_0-rmse:15680.34801
# [62]	validation_0-rmse:15293.89187
# [63]	validation_0-rmse:14941.72761
# [64]	validation_0-rmse:14616.08528
# [65]	validation_0-rmse:14284.51961
# [66]	validation_0-rmse:13961.09331
# [67]	validation_0-rmse:13651.05228
# [68]	validation_0-rmse:13364.40528
# [69]	validation_0-rmse:13094.74183
# [70]	validation_0-rmse:12844.60249
# [71]	validation_0-rmse:12604.50328
# [72]	validation_0-rmse:12370.13183
# [73]	validation_0-rmse:12142.19792
# [74]	validation_0-rmse:11943.50102
# [75]	validation_0-rmse:11738.08773
# [76]	validation_0-rmse:11544.75727
# [77]	validation_0-rmse:11367.49296
# [78]	validation_0-rmse:11206.21161
# [79]	validation_0-rmse:11036.20927
# [80]	validation_0-rmse:10881.03626
# [81]	validation_0-rmse:10740.76252
# [82]	validation_0-rmse:10607.78990
# [83]	validation_0-rmse:10479.04940
# [84]	validation_0-rmse:10356.89881
# [85]	validation_0-rmse:10240.61919
# [86]	validation_0-rmse:10126.15809
# [87]	validation_0-rmse:10028.16831
# [88]	validation_0-rmse:9922.08781
# [89]	validation_0-rmse:9839.65187
# [90]	validation_0-rmse:9751.68853
# [91]	validation_0-rmse:9666.39520
# [92]	validation_0-rmse:9578.74560
# [93]	validation_0-rmse:9487.67659
# [94]	validation_0-rmse:9414.12433
# [95]	validation_0-rmse:9351.26870
# [96]	validation_0-rmse:9278.81166
# [97]	validation_0-rmse:9205.24702
# [98]	validation_0-rmse:9138.62601
# [99]	validation_0-rmse:9086.32165
# [100]	validation_0-rmse:9029.30445
# [101]	validation_0-rmse:8968.82072
# [102]	validation_0-rmse:8904.64014
# [103]	validation_0-rmse:8854.63524
# [104]	validation_0-rmse:8808.10275
# [105]	validation_0-rmse:8762.03289
# [106]	validation_0-rmse:8706.88401
# [107]	validation_0-rmse:8660.27428
# [108]	validation_0-rmse:8605.34310
# [109]	validation_0-rmse:8562.30792
# [110]	validation_0-rmse:8522.34994
# [111]	validation_0-rmse:8470.53439
# [112]	validation_0-rmse:8427.03191
# [113]	validation_0-rmse:8394.15669
# [114]	validation_0-rmse:8359.00102
# [115]	validation_0-rmse:8301.29735
# [116]	validation_0-rmse:8260.81491
# [117]	validation_0-rmse:8235.49115
# [118]	validation_0-rmse:8212.82366
# [119]	validation_0-rmse:8165.14303
# [120]	validation_0-rmse:8120.75065
# [121]	validation_0-rmse:8095.89993
# [122]	validation_0-rmse:8064.33438
# [123]	validation_0-rmse:8027.09559
# [124]	validation_0-rmse:8005.56361
# [125]	validation_0-rmse:7969.99715
# [126]	validation_0-rmse:7920.45018
# [127]	validation_0-rmse:7882.10293
# [128]	validation_0-rmse:7852.03098
# [129]	validation_0-rmse:7822.45764
# [130]	validation_0-rmse:7781.48935
# [131]	validation_0-rmse:7750.20625
# [132]	validation_0-rmse:7722.49483
# [133]	validation_0-rmse:7701.32524
# [134]	validation_0-rmse:7652.36848
# [135]	validation_0-rmse:7630.39923
# [136]	validation_0-rmse:7602.02619
# [137]	validation_0-rmse:7568.17374
# [138]	validation_0-rmse:7545.93153
# [139]	validation_0-rmse:7508.02927
# [140]	validation_0-rmse:7466.30979
# [141]	validation_0-rmse:7437.42108
# [142]	validation_0-rmse:7394.70520
# [143]	validation_0-rmse:7370.66618
# [144]	validation_0-rmse:7347.03580
# [145]	validation_0-rmse:7316.17637
# [146]	validation_0-rmse:7296.30611
# [147]	validation_0-rmse:7281.44306
# [148]	validation_0-rmse:7254.56843
# [149]	validation_0-rmse:7221.10184
# [150]	validation_0-rmse:7202.56220
# [151]	validation_0-rmse:7177.85234
# [152]	validation_0-rmse:7157.95580
# [153]	validation_0-rmse:7128.19016
# [154]	validation_0-rmse:7106.67557
# [155]	validation_0-rmse:7091.07698
# [156]	validation_0-rmse:7066.14913
# [157]	validation_0-rmse:7043.76174
# [158]	validation_0-rmse:7025.42177
# [159]	validation_0-rmse:6999.91568
# [160]	validation_0-rmse:6970.65162
# [161]	validation_0-rmse:6955.50058
# [162]	validation_0-rmse:6936.69582
# [163]	validation_0-rmse:6909.62056
# [164]	validation_0-rmse:6894.13076
# [165]	validation_0-rmse:6872.36249
# [166]	validation_0-rmse:6844.26544
# [167]	validation_0-rmse:6819.26543
# [168]	validation_0-rmse:6797.28105
# [169]	validation_0-rmse:6774.38508
# [170]	validation_0-rmse:6758.79520
# [171]	validation_0-rmse:6741.77965
# [172]	validation_0-rmse:6730.87340
# [173]	validation_0-rmse:6708.41212
# [174]	validation_0-rmse:6678.61603
# [175]	validation_0-rmse:6649.12389
# [176]	validation_0-rmse:6629.53076
# [177]	validation_0-rmse:6609.00338
# [178]	validation_0-rmse:6595.02513
# [179]	validation_0-rmse:6582.97152
# [180]	validation_0-rmse:6564.83623
# [181]	validation_0-rmse:6532.96549
# [182]	validation_0-rmse:6517.05318
# [183]	validation_0-rmse:6498.45271
# [184]	validation_0-rmse:6476.16443
# [185]	validation_0-rmse:6464.95716
# [186]	validation_0-rmse:6445.79547
# [187]	validation_0-rmse:6428.25495
# [188]	validation_0-rmse:6411.93595
# [189]	validation_0-rmse:6388.45639
# [190]	validation_0-rmse:6372.14857
# [191]	validation_0-rmse:6352.76615
# [192]	validation_0-rmse:6343.64305
# [193]	validation_0-rmse:6332.48663
# [194]	validation_0-rmse:6314.16159
# [195]	validation_0-rmse:6289.32531
# [196]	validation_0-rmse:6271.40383
# [197]	validation_0-rmse:6254.95872
# [198]	validation_0-rmse:6241.28715
# [199]	validation_0-rmse:6224.56486
# [200]	validation_0-rmse:6216.35291
# [201]	validation_0-rmse:6206.02405
# [202]	validation_0-rmse:6187.23220
# [203]	validation_0-rmse:6166.36751
# [204]	validation_0-rmse:6158.81312
# [205]	validation_0-rmse:6141.61715
# [206]	validation_0-rmse:6126.93689
# [207]	validation_0-rmse:6111.79475
# [208]	validation_0-rmse:6094.16581
# [209]	validation_0-rmse:6063.98087
# [210]	validation_0-rmse:6049.78948
# [211]	validation_0-rmse:6035.29877
# [212]	validation_0-rmse:6023.11086
# [213]	validation_0-rmse:6007.49919
# [214]	validation_0-rmse:5996.18571
# [215]	validation_0-rmse:5978.99890
# [216]	validation_0-rmse:5951.81473
# [217]	validation_0-rmse:5936.62847
# [218]	validation_0-rmse:5917.50324
# [219]	validation_0-rmse:5909.38478
# [220]	validation_0-rmse:5892.23001
# [221]	validation_0-rmse:5884.23914
# [222]	validation_0-rmse:5864.78334
# [223]	validation_0-rmse:5845.53279
# [224]	validation_0-rmse:5813.15391
# [225]	validation_0-rmse:5795.92349
# [226]	validation_0-rmse:5781.28951
# [227]	validation_0-rmse:5755.69291
# [228]	validation_0-rmse:5739.05363
# [229]	validation_0-rmse:5722.88093
# [230]	validation_0-rmse:5711.70573
# [231]	validation_0-rmse:5699.87266
# [232]	validation_0-rmse:5685.53906
# [233]	validation_0-rmse:5668.98289
# [234]	validation_0-rmse:5643.23663
# [235]	validation_0-rmse:5622.91075
# [236]	validation_0-rmse:5604.20545
# [237]	validation_0-rmse:5587.62225
# [238]	validation_0-rmse:5566.16909
# [239]	validation_0-rmse:5558.86509
# [240]	validation_0-rmse:5541.50321
# [241]	validation_0-rmse:5524.39968
# [242]	validation_0-rmse:5503.63924
# [243]	validation_0-rmse:5486.79802
# [244]	validation_0-rmse:5465.65268
# [245]	validation_0-rmse:5437.33951
# [246]	validation_0-rmse:5415.93828
# [247]	validation_0-rmse:5402.10295
# [248]	validation_0-rmse:5380.11228
# [249]	validation_0-rmse:5367.26817
# [250]	validation_0-rmse:5354.37682
# [251]	validation_0-rmse:5345.14701
# [252]	validation_0-rmse:5314.78795
# [253]	validation_0-rmse:5301.75730
# [254]	validation_0-rmse:5284.32271
# [255]	validation_0-rmse:5271.12648
# [256]	validation_0-rmse:5261.93240
# [257]	validation_0-rmse:5241.77621
# [258]	validation_0-rmse:5218.14723
# [259]	validation_0-rmse:5208.62197
# [260]	validation_0-rmse:5197.36320
# [261]	validation_0-rmse:5185.57916
# [262]	validation_0-rmse:5173.22678
# [263]	validation_0-rmse:5149.43874
# [264]	validation_0-rmse:5139.11494
# [265]	validation_0-rmse:5118.21030
# [266]	validation_0-rmse:5098.76455
# [267]	validation_0-rmse:5092.58728
# [268]	validation_0-rmse:5077.81078
# [269]	validation_0-rmse:5059.34555
# [270]	validation_0-rmse:5037.74088
# [271]	validation_0-rmse:5022.64497
# [272]	validation_0-rmse:5014.11337
# [273]	validation_0-rmse:5008.74309
# [274]	validation_0-rmse:4990.38654
# [275]	validation_0-rmse:4979.00115
# [276]	validation_0-rmse:4961.60052
# [277]	validation_0-rmse:4946.67686
# [278]	validation_0-rmse:4927.16765
# [279]	validation_0-rmse:4915.66070
# [280]	validation_0-rmse:4900.67080
# [281]	validation_0-rmse:4893.02835
# [282]	validation_0-rmse:4879.84294
# [283]	validation_0-rmse:4870.66149
# [284]	validation_0-rmse:4843.13205
# [285]	validation_0-rmse:4826.60061
# [286]	validation_0-rmse:4817.78566
# [287]	validation_0-rmse:4804.52453
# [288]	validation_0-rmse:4790.60645
# [289]	validation_0-rmse:4781.16742
# [290]	validation_0-rmse:4758.30569
# [291]	validation_0-rmse:4749.90811
# [292]	validation_0-rmse:4740.55527
# [293]	validation_0-rmse:4723.99312
# [294]	validation_0-rmse:4701.32641
# [295]	validation_0-rmse:4691.26482
# [296]	validation_0-rmse:4670.10144
# [297]	validation_0-rmse:4656.55544
# [298]	validation_0-rmse:4636.50418
# [299]	validation_0-rmse:4632.10059
# [300]	validation_0-rmse:4615.64149
# [301]	validation_0-rmse:4604.12523
# [302]	validation_0-rmse:4590.55462
# [303]	validation_0-rmse:4584.62209
# [304]	validation_0-rmse:4576.36563
# [305]	validation_0-rmse:4558.07972
# [306]	validation_0-rmse:4535.40025
# [307]	validation_0-rmse:4523.37279
# [308]	validation_0-rmse:4491.14247
# [309]	validation_0-rmse:4471.84265
# [310]	validation_0-rmse:4453.86106
# [311]	validation_0-rmse:4441.51382
# [312]	validation_0-rmse:4430.29112
# [313]	validation_0-rmse:4422.17890
# [314]	validation_0-rmse:4412.01986
# [315]	validation_0-rmse:4407.79950
# [316]	validation_0-rmse:4394.75487
# [317]	validation_0-rmse:4387.00959
# [318]	validation_0-rmse:4357.36533
# [319]	validation_0-rmse:4348.72150
# [320]	validation_0-rmse:4335.60523
# [321]	validation_0-rmse:4316.14857
# [322]	validation_0-rmse:4304.69881
# [323]	validation_0-rmse:4292.71582
# [324]	validation_0-rmse:4284.38527
# [325]	validation_0-rmse:4275.62749
# [326]	validation_0-rmse:4257.29934
# [327]	validation_0-rmse:4251.22941
# [328]	validation_0-rmse:4241.52183
# [329]	validation_0-rmse:4231.13486
# [330]	validation_0-rmse:4225.35871
# [331]	validation_0-rmse:4220.80760
# [332]	validation_0-rmse:4210.22835
# [333]	validation_0-rmse:4195.94643
# [334]	validation_0-rmse:4193.17325
# [335]	validation_0-rmse:4181.49862
# [336]	validation_0-rmse:4163.42053
# [337]	validation_0-rmse:4157.39344
# [338]	validation_0-rmse:4149.07465
# [339]	validation_0-rmse:4142.74513
# [340]	validation_0-rmse:4130.68474
# [341]	validation_0-rmse:4124.33742
# [342]	validation_0-rmse:4119.49640
# [343]	validation_0-rmse:4100.11548
# [344]	validation_0-rmse:4096.96496
# [345]	validation_0-rmse:4087.86073
# [346]	validation_0-rmse:4069.43714
# [347]	validation_0-rmse:4062.99703
# [348]	validation_0-rmse:4040.89489
# [349]	validation_0-rmse:4019.01793
# [350]	validation_0-rmse:4006.81016
# [351]	validation_0-rmse:4003.84314
# [352]	validation_0-rmse:3997.36839
# [353]	validation_0-rmse:3969.73151
# [354]	validation_0-rmse:3953.71158
# [355]	validation_0-rmse:3944.65744
# [356]	validation_0-rmse:3936.14498
# [357]	validation_0-rmse:3918.95873
# [358]	validation_0-rmse:3904.63193
# [359]	validation_0-rmse:3897.52134
# [360]	validation_0-rmse:3887.85201
# [361]	validation_0-rmse:3879.17409
# [362]	validation_0-rmse:3872.94239
# [363]	validation_0-rmse:3867.35166
# [364]	validation_0-rmse:3860.74316
# [365]	validation_0-rmse:3850.29926
# [366]	validation_0-rmse:3844.54127
# [367]	validation_0-rmse:3830.08071
# [368]	validation_0-rmse:3821.87298
# [369]	validation_0-rmse:3809.62094
# [370]	validation_0-rmse:3797.43508
# [371]	validation_0-rmse:3792.76295
# [372]	validation_0-rmse:3779.52891
# [373]	validation_0-rmse:3767.03610
# [374]	validation_0-rmse:3762.43236
# [375]	validation_0-rmse:3753.80402
# [376]	validation_0-rmse:3746.80812
# [377]	validation_0-rmse:3741.53425
# [378]	validation_0-rmse:3733.36943
# [379]	validation_0-rmse:3714.89911
# [380]	validation_0-rmse:3703.68425
# [381]	validation_0-rmse:3699.11213
# [382]	validation_0-rmse:3678.61217
# [383]	validation_0-rmse:3667.14384
# [384]	validation_0-rmse:3652.69182
# [385]	validation_0-rmse:3645.35421
# [386]	validation_0-rmse:3642.22187
# [387]	validation_0-rmse:3636.81777
# [388]	validation_0-rmse:3631.86916
# [389]	validation_0-rmse:3629.16073
# [390]	validation_0-rmse:3613.33159
# [391]	validation_0-rmse:3604.37862
# [392]	validation_0-rmse:3601.52942
# [393]	validation_0-rmse:3591.43692
# [394]	validation_0-rmse:3579.82967
# [395]	validation_0-rmse:3574.82575
# [396]	validation_0-rmse:3568.88061
# [397]	validation_0-rmse:3555.81417
# [398]	validation_0-rmse:3542.08036
# [399]	validation_0-rmse:3537.34802
# [400]	validation_0-rmse:3520.53367
# [401]	validation_0-rmse:3510.08786
# [402]	validation_0-rmse:3486.01993
# [403]	validation_0-rmse:3479.85778
# [404]	validation_0-rmse:3470.30014
# [405]	validation_0-rmse:3462.89623
# [406]	validation_0-rmse:3456.15079
# [407]	validation_0-rmse:3444.01435
# [408]	validation_0-rmse:3432.65441
# [409]	validation_0-rmse:3430.36847
# [410]	validation_0-rmse:3420.49460
# [411]	validation_0-rmse:3409.49685
# [412]	validation_0-rmse:3400.26868
# [413]	validation_0-rmse:3393.86985
# [414]	validation_0-rmse:3386.38066
# [415]	validation_0-rmse:3382.49319
# [416]	validation_0-rmse:3375.09098
# [417]	validation_0-rmse:3369.12557
# [418]	validation_0-rmse:3364.90844
# [419]	validation_0-rmse:3354.08724
# [420]	validation_0-rmse:3348.04459
# [421]	validation_0-rmse:3338.26858
# [422]	validation_0-rmse:3330.49901
# [423]	validation_0-rmse:3327.93180
# [424]	validation_0-rmse:3312.80316
# [425]	validation_0-rmse:3311.00663
# [426]	validation_0-rmse:3309.33479
# [427]	validation_0-rmse:3305.41024
# [428]	validation_0-rmse:3300.45616
# [429]	validation_0-rmse:3278.38251
# [430]	validation_0-rmse:3274.20033
# [431]	validation_0-rmse:3271.03658
# [432]	validation_0-rmse:3265.73218
# [433]	validation_0-rmse:3255.31128
# [434]	validation_0-rmse:3232.37257
# [435]	validation_0-rmse:3215.66612
# [436]	validation_0-rmse:3206.63619
# [437]	validation_0-rmse:3191.36395
# [438]	validation_0-rmse:3186.30714
# [439]	validation_0-rmse:3175.08261
# [440]	validation_0-rmse:3169.41227
# [441]	validation_0-rmse:3154.01513
# [442]	validation_0-rmse:3139.73945
# [443]	validation_0-rmse:3127.28193
# [444]	validation_0-rmse:3121.29351
# [445]	validation_0-rmse:3118.02062
# [446]	validation_0-rmse:3102.91719
# [447]	validation_0-rmse:3082.02493
# [448]	validation_0-rmse:3069.80346
# [449]	validation_0-rmse:3057.64804
# [450]	validation_0-rmse:3052.11063
# [451]	validation_0-rmse:3049.57229
# [452]	validation_0-rmse:3046.15107
# [453]	validation_0-rmse:3034.21033
# [454]	validation_0-rmse:3027.88215
# [455]	validation_0-rmse:3026.34737
# [456]	validation_0-rmse:3018.78634
# [457]	validation_0-rmse:3016.00865
# [458]	validation_0-rmse:3007.94850
# [459]	validation_0-rmse:3000.38884
# [460]	validation_0-rmse:2994.85069
# [461]	validation_0-rmse:2985.24041
# [462]	validation_0-rmse:2979.15447
# [463]	validation_0-rmse:2967.71043
# [464]	validation_0-rmse:2965.00530
# [465]	validation_0-rmse:2958.19724
# [466]	validation_0-rmse:2950.60941
# [467]	validation_0-rmse:2944.65053
# [468]	validation_0-rmse:2937.93680
# [469]	validation_0-rmse:2931.55751
# [470]	validation_0-rmse:2929.27894
# [471]	validation_0-rmse:2920.38185
# [472]	validation_0-rmse:2917.61774
# [473]	validation_0-rmse:2900.29562
# [474]	validation_0-rmse:2893.66776
# [475]	validation_0-rmse:2891.19090
# [476]	validation_0-rmse:2886.92467
# [477]	validation_0-rmse:2885.44885
# [478]	validation_0-rmse:2880.71186
# [479]	validation_0-rmse:2875.21732
# [480]	validation_0-rmse:2867.31456
# [481]	validation_0-rmse:2864.41579
# [482]	validation_0-rmse:2859.52350
# [483]	validation_0-rmse:2855.98842
# [484]	validation_0-rmse:2844.29721
# [485]	validation_0-rmse:2839.22140
# [486]	validation_0-rmse:2826.79248
# [487]	validation_0-rmse:2824.57033
# [488]	validation_0-rmse:2821.25998
# [489]	validation_0-rmse:2815.87042
# [490]	validation_0-rmse:2797.03785
# [491]	validation_0-rmse:2784.15686
# [492]	validation_0-rmse:2776.84320
# [493]	validation_0-rmse:2775.19300
# [494]	validation_0-rmse:2766.01368
# [495]	validation_0-rmse:2759.23970
# [496]	validation_0-rmse:2751.86137
# [497]	validation_0-rmse:2745.26599
# [498]	validation_0-rmse:2736.00732
# [499]	validation_0-rmse:2726.42747
# [500]	validation_0-rmse:2716.27297
# [501]	validation_0-rmse:2710.70910
# [502]	validation_0-rmse:2704.07150
# [503]	validation_0-rmse:2696.72147
# [504]	validation_0-rmse:2691.78126
# [505]	validation_0-rmse:2688.61486
# [506]	validation_0-rmse:2682.22236
# [507]	validation_0-rmse:2677.50371
# [508]	validation_0-rmse:2675.48695
# [509]	validation_0-rmse:2660.05979
# [510]	validation_0-rmse:2656.78457
# [511]	validation_0-rmse:2651.71968
# [512]	validation_0-rmse:2638.46125
# [513]	validation_0-rmse:2632.05342
# [514]	validation_0-rmse:2620.68149
# [515]	validation_0-rmse:2611.20938
# [516]	validation_0-rmse:2608.15260
# [517]	validation_0-rmse:2604.56981
# [518]	validation_0-rmse:2595.45479
# [519]	validation_0-rmse:2581.06480
# [520]	validation_0-rmse:2571.85391
# [521]	validation_0-rmse:2558.15550
# [522]	validation_0-rmse:2553.37590
# [523]	validation_0-rmse:2541.35762
# [524]	validation_0-rmse:2538.23673
# [525]	validation_0-rmse:2534.40469
# [526]	validation_0-rmse:2515.62089
# [527]	validation_0-rmse:2497.27830
# [528]	validation_0-rmse:2486.66908
# [529]	validation_0-rmse:2479.13351
# [530]	validation_0-rmse:2475.62085
# [531]	validation_0-rmse:2466.98310
# [532]	validation_0-rmse:2463.09784
# [533]	validation_0-rmse:2458.08621
# [534]	validation_0-rmse:2452.43887
# [535]	validation_0-rmse:2448.00623
# [536]	validation_0-rmse:2446.07780
# [537]	validation_0-rmse:2444.47187
# [538]	validation_0-rmse:2435.49977
# [539]	validation_0-rmse:2428.01281
# [540]	validation_0-rmse:2424.43665
# [541]	validation_0-rmse:2422.33680
# [542]	validation_0-rmse:2413.72116
# [543]	validation_0-rmse:2411.28478
# [544]	validation_0-rmse:2407.21474
# [545]	validation_0-rmse:2395.34809
# [546]	validation_0-rmse:2392.26771
# [547]	validation_0-rmse:2389.46513
# [548]	validation_0-rmse:2382.21238
# [549]	validation_0-rmse:2373.09223
# [550]	validation_0-rmse:2364.49290
# [551]	validation_0-rmse:2354.12973
# [552]	validation_0-rmse:2341.60632
# [553]	validation_0-rmse:2329.28880
# [554]	validation_0-rmse:2327.13261
# [555]	validation_0-rmse:2317.15327
# [556]	validation_0-rmse:2314.46037
# [557]	validation_0-rmse:2307.37973
# [558]	validation_0-rmse:2300.80785
# [559]	validation_0-rmse:2297.14944
# [560]	validation_0-rmse:2287.54230
# [561]	validation_0-rmse:2270.52109
# [562]	validation_0-rmse:2262.58084
# [563]	validation_0-rmse:2257.34111
# [564]	validation_0-rmse:2253.94246
# [565]	validation_0-rmse:2246.16262
# [566]	validation_0-rmse:2235.38921
# [567]	validation_0-rmse:2228.87177
# [568]	validation_0-rmse:2226.74609
# [569]	validation_0-rmse:2216.46271
# [570]	validation_0-rmse:2210.91826
# [571]	validation_0-rmse:2205.68618
# [572]	validation_0-rmse:2196.95003
# [573]	validation_0-rmse:2189.99349
# [574]	validation_0-rmse:2180.57836
# [575]	validation_0-rmse:2178.15439
# [576]	validation_0-rmse:2170.10420
# [577]	validation_0-rmse:2165.90602
# [578]	validation_0-rmse:2163.96115
# [579]	validation_0-rmse:2159.01652
# [580]	validation_0-rmse:2154.70034
# [581]	validation_0-rmse:2150.77512
# [582]	validation_0-rmse:2146.34661
# [583]	validation_0-rmse:2138.95537
# [584]	validation_0-rmse:2125.25204
# [585]	validation_0-rmse:2116.81947
# [586]	validation_0-rmse:2111.59206
# [587]	validation_0-rmse:2105.97182
# [588]	validation_0-rmse:2102.57483
# [589]	validation_0-rmse:2101.04528
# [590]	validation_0-rmse:2096.65041
# [591]	validation_0-rmse:2091.72585
# [592]	validation_0-rmse:2089.63857
# [593]	validation_0-rmse:2080.88074
# [594]	validation_0-rmse:2078.04572
# [595]	validation_0-rmse:2071.38331
# [596]	validation_0-rmse:2066.49951
# [597]	validation_0-rmse:2064.74563
# [598]	validation_0-rmse:2061.01389
# [599]	validation_0-rmse:2054.81577
# [600]	validation_0-rmse:2050.94810
# [601]	validation_0-rmse:2044.57853
# [602]	validation_0-rmse:2040.28958
# [603]	validation_0-rmse:2037.82016
# [604]	validation_0-rmse:2027.95283
# [605]	validation_0-rmse:2024.15721
# [606]	validation_0-rmse:2016.57253
# [607]	validation_0-rmse:2015.06182
# [608]	validation_0-rmse:2012.51368
# [609]	validation_0-rmse:2005.91967
# [610]	validation_0-rmse:1994.43256
# [611]	validation_0-rmse:1989.11855
# [612]	validation_0-rmse:1981.29887
# [613]	validation_0-rmse:1977.30117
# [614]	validation_0-rmse:1967.19278
# [615]	validation_0-rmse:1964.86885
# [616]	validation_0-rmse:1955.41712
# [617]	validation_0-rmse:1950.41115
# [618]	validation_0-rmse:1942.37585
# [619]	validation_0-rmse:1937.37063
# [620]	validation_0-rmse:1932.93431
# [621]	validation_0-rmse:1926.57614
# [622]	validation_0-rmse:1915.60438
# [623]	validation_0-rmse:1907.27013
# [624]	validation_0-rmse:1904.54399
# [625]	validation_0-rmse:1898.76438
# [626]	validation_0-rmse:1897.87948
# [627]	validation_0-rmse:1896.58739
# [628]	validation_0-rmse:1884.69173
# [629]	validation_0-rmse:1881.25235
# [630]	validation_0-rmse:1874.22096
# [631]	validation_0-rmse:1872.03683
# [632]	validation_0-rmse:1871.22542
# [633]	validation_0-rmse:1867.16174
# [634]	validation_0-rmse:1863.49489
# [635]	validation_0-rmse:1861.88833
# [636]	validation_0-rmse:1855.18921
# [637]	validation_0-rmse:1850.07810
# [638]	validation_0-rmse:1848.80542
# [639]	validation_0-rmse:1840.03334
# [640]	validation_0-rmse:1829.29597
# [641]	validation_0-rmse:1827.48691
# [642]	validation_0-rmse:1823.27903
# [643]	validation_0-rmse:1822.08088
# [644]	validation_0-rmse:1820.93044
# [645]	validation_0-rmse:1816.58554
# [646]	validation_0-rmse:1809.17304
# [647]	validation_0-rmse:1799.99250
# [648]	validation_0-rmse:1795.65557
# [649]	validation_0-rmse:1794.15281
# [650]	validation_0-rmse:1785.33528
# [651]	validation_0-rmse:1782.00390
# [652]	validation_0-rmse:1779.09821
# [653]	validation_0-rmse:1769.76209
# [654]	validation_0-rmse:1761.74785
# [655]	validation_0-rmse:1758.78877
# [656]	validation_0-rmse:1757.71399
# [657]	validation_0-rmse:1749.28951
# [658]	validation_0-rmse:1743.23519
# [659]	validation_0-rmse:1742.26301
# [660]	validation_0-rmse:1739.15054
# [661]	validation_0-rmse:1733.32134
# [662]	validation_0-rmse:1725.79849
# [663]	validation_0-rmse:1723.73095
# [664]	validation_0-rmse:1715.67389
# [665]	validation_0-rmse:1711.58487
# [666]	validation_0-rmse:1706.36316
# [667]	validation_0-rmse:1702.69772
# [668]	validation_0-rmse:1701.17333
# [669]	validation_0-rmse:1696.31597
# [670]	validation_0-rmse:1690.62628
# [671]	validation_0-rmse:1689.10236
# [672]	validation_0-rmse:1686.14113
# [673]	validation_0-rmse:1683.98723
# [674]	validation_0-rmse:1682.15791
# [675]	validation_0-rmse:1679.82213
# [676]	validation_0-rmse:1677.06497
# [677]	validation_0-rmse:1674.43872
# [678]	validation_0-rmse:1673.04780
# [679]	validation_0-rmse:1669.16051
# [680]	validation_0-rmse:1666.50244
# [681]	validation_0-rmse:1661.94992
# [682]	validation_0-rmse:1656.82070
# [683]	validation_0-rmse:1653.78947
# [684]	validation_0-rmse:1652.11454

# %%
y_pred.head()

# %%
y_pred_path = os.path.join('data', 'xgb_predictions.csv')

y_pred.to_csv(y_pred_path, index = True)
